# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt

# %%
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
image = cv2.imread("../data/youtube_videos/frames/1/300.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

image_height, image_width, _ = image.shape

plt.imshow(image)

# %%
pose = mp_pose.Pose(static_image_mode=True,
                    model_complexity=2,
                    enable_segmentation=True,
                    min_detection_confidence=0.5)

# %%
results = pose.process(image)

# %%
# Get specific landmark
results.pose_landmarks.landmark[mp_pose.PoseLandmark.LEFT_ANKLE]
# Out:
# x: 0.825638473033905
# y: 0.7412450313568115
# z: 0.40034908056259155
# visibility: 0.7766224145889282

# %%
annotated_image = image.copy()

mp_drawing.draw_landmarks(
    annotated_image,
    results.pose_landmarks,
    mp_pose.POSE_CONNECTIONS
)

plt.imshow(annotated_image)
